# %%
import os
from supabase import create_client, Client
url="https://pupuxvwdywpsyztfplko.supabase.co"
key="eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6InB1cHV4dndkeXdwc3l6dGZwbGtvIiwicm9sZSI6ImFub24iLCJpYXQiOjE2OTkwMDIzODksImV4cCI6MjAxNDU3ODM4OX0.mdma0Kgg1tBbY-wVxju_0an4e43RXwBnhY_v8PWqyZE"
supabase= create_client(url, key)

# %%
data = supabase.table("IsYerleri").select("*").execute()
print(data)
if data.data == []:
    print("oldu")
# Out:
# 2023-11-11 20:32:48,407:INFO - HTTP Request: GET https://pupuxvwdywpsyztfplko.supabase.co/rest/v1/IsYerleri?select=%2A "HTTP/1.1 200 OK"
# ...

# %%
Isyeri = supabase.table('IsYerleri').select("*").eq("sgkSicilNo","48010010112028750410387000").execute()
if Isyeri.data != []:
    print(Isyeri.data)
# Out:
# 2023-11-12 19:38:35,286:INFO - HTTP Request: GET https://pupuxvwdywpsyztfplko.supabase.co/rest/v1/IsYerleri?select=%2A&sgkSicilNo=eq.48010010112028750410387000 "HTTP/1.1 200 OK"
# [{'id': 2005, 'sirketId': 2, 'bolgeId': 5, 'sapKodu': 'E764', 'isYeriAdi': 'YAPI VE KREDİ BANKASI A.Ş. GÖLCÜK ŞB.', 'kullaniciAdi': '12316108394', 'kullaniciKodu': '3240', 'sistemSifresi': '09GiaM49', 'isYeriSifresi': '47VctH11', 'sgkSicilNo': '48010010112028750410387000', 'isYeriAdresi': '', 'acilisTarihi': '', 'kapanisTarihi': ''}]

# %%
sirket = supabase.table('Sirketler').select('*').eq('sirketKodu', "4840").execute()
if sirket.data != []:
    print(sirket.data)
# Out:
# 2023-11-12 19:38:38,519:INFO - HTTP Request: GET https://pupuxvwdywpsyztfplko.supabase.co/rest/v1/Sirketler?select=%2A&sirketKodu=eq.4840 "HTTP/1.1 200 OK"
# [{'id': 5, 'sirketKodu': 4840, 'sirketAdi': 'TEPE SERVİS KART HİZMETLERİ A.Ş.'}]

# %%
proje = supabase.table('Projeler').select('*').eq('pypOgesi',"175.033.999").execute()
print(len(proje.data))
if proje.data != []:
    print(proje.data)
# Out:
# 2023-11-12 20:03:45,062:INFO - HTTP Request: GET https://pupuxvwdywpsyztfplko.supabase.co/rest/v1/Projeler?select=%2A&pypOgesi=eq.175.033.999 "HTTP/1.1 200 OK"
# 0

# %%
yeni = { 'sirketId': '5','bolgeId': '5', 'sapKodu': 'o432', 'isYeriAdi': 'OKANKKKK', 'kullaniciAdi': '13455054344', 'kullaniciKodu': '293', 'sistemSifresi': '31JgdJ36', 'isYeriSifresi': '152017', 'sgkSicilNo': '48010010111563240331474334', 'isYeriAdresi': '', 'acilisTarihi':None , 'kapanisTarihi': None}
isyeri_ekle_sonuc = supabase.table('IsYerleri').insert(yeni, upsert=True).execute()
# Out:
# 2023-11-12 18:26:02,856:INFO - HTTP Request: POST https://pupuxvwdywpsyztfplko.supabase.co/rest/v1/IsYerleri "HTTP/1.1 201 Created"
# 2023-11-12 18:27:25,906:INFO - HTTP Request: POST https://pupuxvwdywpsyztfplko.supabase.co/auth/v1/token?grant_type=refresh_token "HTTP/1.1 200 OK"
# 2023-11-12 19:12:38,119:INFO - HTTP Request: POST https://pupuxvwdywpsyztfplko.supabase.co/auth/v1/token?grant_type=refresh_token "HTTP/1.1 400 Bad Request"
# 2023-11-12 19:27:14,268:INFO - HTTP Request: POST https://pupuxvwdywpsyztfplko.supabase.co/auth/v1/token?grant_type=refresh_token "HTTP/1.1 400 Bad Request"

# %%
data = supabase.table("Kullanıcılar").select("*").eq("id",2).execute()
print(data)
# Out:
# 2023-11-03 19:22:39,722:INFO - HTTP Request: GET https://pupuxvwdywpsyztfplko.supabase.co/rest/v1/Kullan%C4%B1c%C4%B1lar?select=%2A&id=eq.2 "HTTP/1.1 200 OK"
# data=[] count=None

# %%
data = supabase.table("Kullanıcılar").insert({"Ad":"OKAN","Soyad":"AVCU","KullanıcıAdı":"oavcu","Mail":"oavcu@bilkentohm.com.tr","Admin":1}).execute()

# %%
data = supabase.table("Kullanıcılar").insert({"Ad":"Ahmed Emin","Soyad":"Korkmaz","KullanıcıAdı":"aekorkmaz","Mail":"aekorkmaz@bilkentohm.com.tr"}).execute()
# Out:
# 2023-11-03 14:40:14,231:INFO - HTTP Request: POST https://pupuxvwdywpsyztfplko.supabase.co/rest/v1/Kullan%C4%B1c%C4%B1lar "HTTP/1.1 201 Created"

# %%
data = supabase.table("Kullanıcılar").update({"Ad":"AHMET EMİN","Soyad":"KORKMAZ"}).eq("id", 2).execute()
# Out:
# 2023-11-03 14:33:48,797:INFO - HTTP Request: PATCH https://pupuxvwdywpsyztfplko.supabase.co/rest/v1/Kullan%C4%B1c%C4%B1lar?id=eq.2 "HTTP/1.1 200 OK"

# %%
data = supabase.table("Kullanıcılar").delete().eq("id", 3).execute()
# Out:
# 2023-11-03 14:41:40,487:INFO - HTTP Request: DELETE https://pupuxvwdywpsyztfplko.supabase.co/rest/v1/Kullan%C4%B1c%C4%B1lar?id=eq.3 "HTTP/1.1 200 OK"

# %%
res = supabase.auth.sign_up({
  "email": 'mnaziki@bilkentohm.com.tr',
  "password": '23061994ss',
  "options": {
    "data": {
      "Adı": 'MELİH',
      "SoyAdı": 'NAZİK',
      "Admin": True,
      "Bölgeleri": [4],
      "Şirketleri": [2,5],
    }
  }
})
# Out:
# 2023-11-05 13:22:04,336:INFO - HTTP Request: POST https://pupuxvwdywpsyztfplko.supabase.co/auth/v1/signup "HTTP/1.1 200 OK"

# %%
session = supabase.auth.sign_in_with_password({"email": 'oavcu@bilkentohm.com.tr', "password": '23061994ss'})
supabase.postgrest.auth(session.session.access_token)
print(session)

data = supabase.table("IsYerleri").select("*").execute()
print(data)

# supabase.auth.sign_out()
# Out:
# 2023-11-12 23:38:56,677:INFO - HTTP Request: POST https://pupuxvwdywpsyztfplko.supabase.co/auth/v1/token?grant_type=password "HTTP/1.1 200 OK"
# ...

# %%
import pandas as pd


bolge = supabase.table('Bolgeler').select('bolge').execute()
print(bolge.data)
df = pd.DataFrame(bolge.data)
print(df)
# Out:
# 2023-11-12 23:43:01,309:INFO - HTTP Request: GET https://pupuxvwdywpsyztfplko.supabase.co/rest/v1/Bolgeler?select=bolge "HTTP/1.1 200 OK"
# [{'bolge': 'AKDENİZ'}, {'bolge': 'İDARİ İŞYERİ'}, {'bolge': 'ÇUKUROVA'}, {'bolge': 'MERKEZ'}, {'bolge': 'MARMARA'}, {'bolge': 'BURSA'}, {'bolge': 'EGE'}]
#           bolge
# 0       AKDENİZ
# 1  İDARİ İŞYERİ
# 2      ÇUKUROVA
# 3        MERKEZ
# 4       MARMARA
# 5         BURSA
# 6           EGE

# %%
# bölgeler = session.user.user_metadata['Bölgeleri']
# şirketler = session.user.user_metadata['Şirketleri']
# # Bölgeleri listesini ve Şirketleri listesini istediğiniz gibi değiştirin
# bölgeler.append(4) # Bölge 7'i çıkarın
# şirketler.append(4) # Şirket 6'yı çıkarın
# # Kullanıcının user_metadata daki Bölgeleri listesini ve Şirketleri listesini güncelleyin
# supabase.auth.update_user({"user_metadata": {"Bölgeleri": bölgeler, "Şirketleri": şirketler}})
supabase.auth.sign_out()
# Out:
# 2023-11-12 22:38:14,067:INFO - HTTP Request: POST https://pupuxvwdywpsyztfplko.supabase.co/auth/v1/logout "HTTP/1.1 204 No Content"

# %%
bölgeler = session.user.user_metadata['Bölgeleri']
şirketler = session.user.user_metadata['Şirketleri']

print("Bölgeleri:", bölgeler)
print("Şirketleri:", şirketler)
# Out:
# Bölgeleri: [1, 2, 3, 4, 5, 6, 7]
# Şirketleri: [1, 2, 3, 4, 5, 6, 7, 8]

# %%
response = supabase.table('IsYerleri').select('id,from:sirketId(id),to:Sirketler(sirketKodu)').execute()
print(response)
# Out:
# 2023-11-05 15:23:49,169:INFO - HTTP Request: GET https://pupuxvwdywpsyztfplko.supabase.co/rest/v1/IsYerleri?select=id%2Cfrom%3AsirketId%28id%29%2Cto%3ASirketler%28sirketKodu%29 "HTTP/1.1 200 OK"
# ...

# %%
pip install pandas
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.

# %%
response = supabase.rpc('tablogetir', params={})

# RPC çağrısının yanıtını alın
result = response.execute()

print(response)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Okan Avcu\Desktop\Python\Streamlit\deneme.ipynb Hücre 16 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Okan%20Avcu/Desktop/Python/Streamlit/deneme.ipynb#X21sZmlsZQ%3D%3D?line=0'>1</a> response = supabase.rpc('tablogetir', params={})
#       <a href='vscode-notebook-cell:/c%3A/Users/Okan%20Avcu/Desktop/Python/Streamlit/deneme.ipynb#X21sZmlsZQ%3D%3D?line=2'>3</a> # RPC çağrısının yanıtını alın
#       <a href='vscode-notebook-cell:/c%3A/Users/Okan%20Avcu/Desktop/Python/Streamlit/deneme.ipynb#X21sZmlsZQ%3D%3D?line=3'>4</a> result = response.execute()
#
# NameError: name 'supabase' is not defined

# %%
formdegeri = {'sirketId': 5, 'bolgeId': 5, 'sapKodu': 'T554', 'isYeriAdi': 'BENZERSİZ BİR YER', 'kullaniciAdi': '13455054344', 'kullaniciKodu': '293', 'sistemSifresi': '31JgdJ36', 'isYeriSifresi': '152017', 'sgkSicilNo': '48010010111563240331479452', 'isYeriAdresi': '', 'acilisTarihi': None, 'kapanisTarihi': None}

# %%
isyeri_sorgu = supabase.table('IsYerleri').select('*').eq('sgkSicilNo', formdegeri['sgkSicilNo']).execute()
if len(isyeri_sorgu.data) > 0:
    isyerisicil = isyeri_sorgu.data[0]['sgkSicilNo']
else:
    isyerisicil = None
# Out:
# 2023-11-12 22:38:41,097:INFO - HTTP Request: GET https://pupuxvwdywpsyztfplko.supabase.co/rest/v1/IsYerleri?select=%2A&sgkSicilNo=eq.48010010111563240331479452 "HTTP/1.1 200 OK"

# %%
bolge = supabase.table('Bolgeler').select('*').eq('bolge', formdegeri['bolge']).execute()
if len(bolge.data) > 0:
    bolgeId = bolge.data[0]['id']
else:
    bolgeId = None
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\Okan Avcu\Desktop\Python\Streamlit\deneme.ipynb Hücre 21 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Okan%20Avcu/Desktop/Python/Streamlit/deneme.ipynb#X31sZmlsZQ%3D%3D?line=0'>1</a> bolge = supabase.table('Bolgeler').select('*').eq('bolge', formdegeri['bolge']).execute()
#       <a href='vscode-notebook-cell:/c%3A/Users/Okan%20Avcu/Desktop/Python/Streamlit/deneme.ipynb#X31sZmlsZQ%3D%3D?line=1'>2</a> if len(bolge.data) > 0:
#       <a href='vscode-notebook-cell:/c%3A/Users/Okan%20Avcu/Desktop/Python/Streamlit/deneme.ipynb#X31sZmlsZQ%3D%3D?line=2'>3</a>     bolgeId = bolge.data[0]['id']
#
# KeyError: 'bolge'

# %%
sirket = supabase.table('Sirketler').select('*').eq('sirketKodu', formdegeri['sirketKod']).execute()
if len(sirket.data) > 0:
    sirket_id = sirket.data[0]['id']
else:
    sirket_id = None
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\Okan Avcu\Desktop\Python\Streamlit\deneme.ipynb Hücre 22 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Okan%20Avcu/Desktop/Python/Streamlit/deneme.ipynb#X32sZmlsZQ%3D%3D?line=0'>1</a> sirket = supabase.table('Sirketler').select('*').eq('sirketKodu', formdegeri['sirketKod']).execute()
#       <a href='vscode-notebook-cell:/c%3A/Users/Okan%20Avcu/Desktop/Python/Streamlit/deneme.ipynb#X32sZmlsZQ%3D%3D?line=1'>2</a> if len(sirket.data) > 0:
#       <a href='vscode-notebook-cell:/c%3A/Users/Okan%20Avcu/Desktop/Python/Streamlit/deneme.ipynb#X32sZmlsZQ%3D%3D?line=2'>3</a>     sirket_id = sirket.data[0]['id']
#
# KeyError: 'sirketKod'

# %%
proje = supabase.table('Projeler').select('*').eq('pypOgesi', formdegeri['pypOgesi']).execute()
if 'data' in proje and len(proje.data) > 0:
    proje_id = proje.data[0]['id']
else:
    proje_id = None
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\Okan Avcu\Desktop\Python\Streamlit\deneme.ipynb Hücre 23 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Okan%20Avcu/Desktop/Python/Streamlit/deneme.ipynb#X33sZmlsZQ%3D%3D?line=0'>1</a> proje = supabase.table('Projeler').select('*').eq('pypOgesi', formdegeri['pypOgesi']).execute()
#       <a href='vscode-notebook-cell:/c%3A/Users/Okan%20Avcu/Desktop/Python/Streamlit/deneme.ipynb#X33sZmlsZQ%3D%3D?line=1'>2</a> if 'data' in proje and len(proje.data) > 0:
#       <a href='vscode-notebook-cell:/c%3A/Users/Okan%20Avcu/Desktop/Python/Streamlit/deneme.ipynb#X33sZmlsZQ%3D%3D?line=2'>3</a>     proje_id = proje.data[0]['id']
#
# KeyError: 'pypOgesi'

# %%
isyeri_ekle_sonuc = supabase.table('IsYerleri').insert([formdegeri]).execute()
# Out:
# 2023-11-12 22:46:32,451:INFO - HTTP Request: POST https://pupuxvwdywpsyztfplko.supabase.co/rest/v1/IsYerleri "HTTP/1.1 201 Created"
